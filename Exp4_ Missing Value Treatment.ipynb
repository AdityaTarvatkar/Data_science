# %% [markdown]
# # Missing Value Treatment

# %%
#Exp no.:4

# %%
#Aim : Missing value treatment

# %%
#Name:Mihir A Deshmukh
#Roll no.:8
#Section:3B
#Subject:DSS
#Date:14/08/2025

# %%
#importing the basic library
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Music'

# %%
os.chdir('C:\\Users\\user\\Desktop')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 os.chdir('C:\\Users\\user\\Desktop')
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\user\\Desktop'

# %%
data=pd.read_csv("titanic.csv")

# %%
data.head(10)

# %%
data.tail()

# %%
data.size

# %%
data.shape

# %%
data.ndim

# %%
data.columns

# %%
data.info()

# %%
data.describe()

# %%
data

# %%
data.isna()

# %%
data.isna().any()

# %%
data.isna().sum()

# %%
data["Age"].fillna(29.699118)

# %%
data.isna().sum()

# %%
data=data.dropna()

# %%
data.isna().sum()
